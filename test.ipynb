# %%
import pandas as pd

PATH = "data/processed/features_daily.parquet"

df = pd.read_parquet(PATH)

print("Nombre de lignes :", len(df))
print("Dates :", df["date"].min(), "->", df["date"].max())

# Afficher toutes les lignes
pd.set_option("display.max_rows", None)
print("\nContenu complet :")
print(df)
# Out:
# Nombre de lignes : 29
# Dates : 2024-01-01 00:00:00 -> 2024-01-29 00:00:00
#
# Contenu complet :
#          date  ca_total  nb_commandes     label
# 0  2024-01-01  17462.48           334  15585.04
# 1  2024-01-02  15585.04           333  16608.91
# 2  2024-01-03  16608.91           333  16954.03
# 3  2024-01-04  16954.03           334  16840.54
# 4  2024-01-05  16840.54           333  17392.02
# 5  2024-01-06  17392.02           333  17113.43
# 6  2024-01-07  17113.43           334  16731.88
# 7  2024-01-08  16731.88           333  15857.41
# 8  2024-01-09  15857.41           333  16157.18
# 9  2024-01-10  16157.18           334  17279.23
# 10 2024-01-11  17279.23           333  16966.15
# 11 2024-01-12  16966.15           333  16295.33
# 12 2024-01-13  16295.33           333  16204.02
# 13 2024-01-14  16204.02           334  16894.19
# 14 2024-01-15  16894.19           333  16559.92
# 15 2024-01-16  16559.92           333  17152.51
# 16 2024-01-17  17152.51           334  17726.17
# 17 2024-01-18  17726.17           333  16491.79
# 18 2024-01-19  16491.79           333  16998.82
# 19 2024-01-20  16998.82           334  16780.09
# 20 2024-01-21  16780.09           333  16807.15
# 21 2024-01-22  16807.15           333  17218.88
# 22 2024-01-23  17218.88           333  17580.35
# 23 2024-01-24  17580.35           334  16085.82
# 24 2024-01-25  16085.82           333  16256.25
# 25 2024-01-26  16256.25           333  16921.07
# 26 2024-01-27  16921.07           334  16888.88
# 27 2024-01-28  16888.88           333  17384.13
# 28 2024-01-29  17384.13           333  16279.35
